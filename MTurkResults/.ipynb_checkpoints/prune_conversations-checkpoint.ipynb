# %%
import sys
sys.path.insert(0, '/home/sos/Dialogue_Research/color_in_context/system/dialogue_manager')
from task_manager.task_manager import task_manager
import json
import pandas as pd
import os

# %%
dirname = 'conversations_v1/'
ids_to_ignore = ['', 'hahah', 'baber', 'rrr', '1234', 'Rose']
ids = set()
all_csvs = []
for i, conv in enumerate(os.listdir(dirname)):
    convo_dict = json.load(open(dirname + conv, 'r'))
    csv_dict = dict()
    if len(convo_dict) >= 2:
        flag = True
        for turn in convo_dict:
            if 'name' not in turn:
                continue
            if turn['name'] == 'S':
            print(turn)
# Out:
# {'condition': 'split'}
# {'name': 'S', 'text': 'A9EVF0SO2IUJ0', 'timestamp': '2020-05-01 18:47:54.284426', 'finished': 0}
# {'name': 'S', 'text': 'Violet', 'timestamp': '2020-05-01 18:48:04.565526', 'finished': 0}
# {'name': 'L', 'text': 'The magenta?', 'info': '', 'timestamp': '2020-05-01 18:48:04.586356', 'finished': 0}
# {'name': 'S', 'text': 'yes', 'timestamp': '2020-05-01 18:48:11.545138', 'finished': 0}
# {'name': 'L', 'info': '', 'text': '', 'success': 0, 'timestamp': '2020-05-01 18:48:11.549905', 'finished': 1}
# {'condition': 'far'}
# {'name': 'S', 'text': 'A3BJTC39BU7R4V', 'timestamp': '2020-05-01 21:19:34.565340', 'finished': 0}
# {'name': 'S', 'text': 'ok', 'timestamp': '2020-05-01 21:19:43.259279', 'finished': 0}
# {'name': 'L', 'text': 'I could not understand you.', 'info': '', 'timestamp': '2020-05-01 21:19:43.261892', 'finished': 0}
# {'name': 'S', 'text': 'What do i need to do', 'timestamp': '2020-05-01 21:19:50.689258', 'finished': 0}
# ...
